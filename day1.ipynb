# %% [markdown]
# <a href="https://colab.research.google.com/github/fators22/FNLProject/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=5
if x == 2:
  print("x must be 2")
else:
  if x == 3:
    print("x must be 3")
  else:
    print("x must be something else")
# Out:
# x must be something else

# %% [markdown]
# Declare variables before it is used. x gave error because it was not declared.

# %%
# Single comment anything after a # is a comment
# At this point we wish to print out some numbers and see where that gets us
print("print this!")
# Out:
# print this!

# %%
string1 = "sebastian"
index=len(string1) // 4
middle = string1[index]
print(middle)
# Out:
# b

# %%
import kagglehub
path = kagglehub.dataset_download("dgawlik/nyse")
print(path)
# Out:
# ...
# 100%|██████████| 30.7M/30.7M [00:00<00:00, 137MB/s]
# Extracting files...
# /root/.cache/kagglehub/datasets/dgawlik/nyse/versions/3

# %%
import pandas as pd

url=path+"fundamentals.csv"



print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10534/1211946765.py in <cell line: 0>()
#       3 url=path+"fundamentals.csv"
#       4
# ----> 5 df=pd.read_csv(url);
#       6
#       7 print(df)
#
# ...
